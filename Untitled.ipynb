# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('files_for_lab/csv_files/marketing_customer_analysis.csv', sep=',')
data.head()
# Out:
#    Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# 0     Basic   College           2/18/11         Employed      M  ...
# 1     Basic   College           1/18/11       Unemployed      F  ...
# 2     Basic  Bachelor           2/10/11         Employed      M  ...
# 3  Extended   College           1/11/11         Employed      M  ...
# 4   Premium  Bachelor           1/17/11    Medical Leave      F  ...
#
#    Number of Open Complaints Number of Policies     Policy Type        Policy  \
# 0                        0.0                  9  Corporate Auto  Corporate L3
# 1                        0.0                  1   Personal Auto   Personal L3
# 2                        0.0                  2   Personal Auto   Personal L3
# 3                        0.0                  2  Corporate Auto  Corporate L3
# 4                        NaN                  7   Personal Auto   Personal L2
#
#    Renew Offer Type  Sales Channel  Total Claim Amount  Vehicle Class  \
# 0            Offer3          Agent          292.800000  Four-Door Car
# 1            Offer4    Call Center          744.924331  Four-Door Car
# 2            Offer3    Call Center          480.000000            SUV
# 3            Offer2         Branch          484.013411  Four-Door Car
# 4            Offer1         Branch          707.925645  Four-Door Car
#
#   Vehicle Size Vehicle Type
# 0      Medsize          NaN
# 1      Medsize          NaN
# 2      Medsize            A
# 3      Medsize            A
# 4      Medsize          NaN
#
# [5 rows x 26 columns]

# %%
data.shape
# Out:
# (10910, 26)

# %%
standart_names = lambda x: x.lower()
#data.columns=list(data.columns).apply(standart_names)
data.columns = [standart_names(item) for item in list(data.columns)]
data.head()
# Out:
#    unnamed: 0 customer       state  customer lifetime value response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    coverage education effective to date employmentstatus gender  ...  \
# 0     Basic   College           2/18/11         Employed      M  ...
# 1     Basic   College           1/18/11       Unemployed      F  ...
# 2     Basic  Bachelor           2/10/11         Employed      M  ...
# 3  Extended   College           1/11/11         Employed      M  ...
# 4   Premium  Bachelor           1/17/11    Medical Leave      F  ...
#
#    number of open complaints number of policies     policy type        policy  \
# 0                        0.0                  9  Corporate Auto  Corporate L3
# 1                        0.0                  1   Personal Auto   Personal L3
# 2                        0.0                  2   Personal Auto   Personal L3
# 3                        0.0                  2  Corporate Auto  Corporate L3
# 4                        NaN                  7   Personal Auto   Personal L2
#
#    renew offer type  sales channel  total claim amount  vehicle class  \
# 0            Offer3          Agent          292.800000  Four-Door Car
# 1            Offer4    Call Center          744.924331  Four-Door Car
# 2            Offer3    Call Center          480.000000            SUV
# 3            Offer2         Branch          484.013411  Four-Door Car
# 4            Offer1         Branch          707.925645  Four-Door Car
#
#   vehicle size vehicle type
# 0      Medsize          NaN
# 1      Medsize          NaN
# 2      Medsize            A
# 3      Medsize            A
# 4      Medsize          NaN
#
# [5 rows x 26 columns]

# %%
data.describe(include=['float64',])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/40/fpzt8rqs1hd_nf7fht4s6n240000gn/T/ipykernel_2382/723747887.py in <module>
# ----> 1 data.describe(include='numerical')
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in describe(self, percentiles, include, exclude, datetime_is_numeric)
#   10022         max            NaN      3.0
#   10023         """
# > 10024         return describe_ndframe(
#   10025             obj=self,
#   10026             include=include,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/describe.py in describe_ndframe(obj, include, exclude, datetime_is_numeric, percentiles)
#      93         )
#      94
# ---> 95     result = describer.describe(percentiles=percentiles)
#      96     return cast(FrameOrSeries, result)
#      97
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/describe.py in describe(self, percentiles)
#     168
#     169     def describe(self, percentiles: Sequence[float]) -> DataFrame:
# --> 170         data = self._select_data()
#     171
#     172         ldesc: list[Series] = []
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/describe.py in _select_data(self)
#     202             data = self.obj
#     203         else:
# --> 204             data = self.obj.select_dtypes(
#     205                 include=self.include,
#     206                 exclude=self.exclude,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in select_dtypes(self, include, exclude)
#    4304             return frozenset(converted_dtypes)
#    4305
# -> 4306         include = check_int_infer_dtype(include)
#    4307         exclude = check_int_infer_dtype(exclude)
#    4308
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in check_int_infer_dtype(dtypes)
#    4300                     # "Type[signedinteger[Any]]"
#    4301                     converted_dtypes.append(
# -> 4302                         infer_dtype_from_object(dtype)  # type: ignore[arg-type]
#    4303                     )
#    4304             return frozenset(converted_dtypes)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/common.py in infer_dtype_from_object(dtype)
#    1687             pass
#    1688
# -> 1689     return infer_dtype_from_object(np.dtype(dtype))
#    1690
#    1691
#
# TypeError: data type 'numerical' not understood
